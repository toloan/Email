# %%
ls -la
# Out:
# total 36
# drwxr-xr-x 1 root root 4096 May 10 02:16 ./
# drwxr-xr-x 1 root root 4096 May 10 02:04 ../
# drwx------ 4 root root 4096 May 10 02:16 .cache/
# drwxr-xr-x 3 root root 4096 May 10 02:16 .config/
# drwxr-xr-x 1 root root 4096 Apr 30 16:29 datalab/
# drwxr-xr-x 4 root root 4096 May 10 02:05 .forever/
# drwxr-xr-x 5 root root 4096 May 10 02:16 .ipython/
# drwx------ 3 root root 4096 May 10 02:05 .local/
# -rw------- 1 root root 1024 May 10 02:05 .rnd

# %%
print("Ok")

# %%
print("abc")
